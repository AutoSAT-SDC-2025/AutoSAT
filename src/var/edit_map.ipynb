# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt

# %%
map = cv.imread("/home/thimo/Seafile/Git/AutoSAT/src/var/map.png")

# %%
plt.imshow(map)

# %%
left = map[:, :2600]
plt.imshow(left)

# %%
right = map[:,2700:]
plt.imshow(right)

# %%
result = np.concatenate((left, right), axis=1)
plt.imshow(result)
map = result

# %%
left = map[:, :1800]
plt.imshow(left)

# %%
right = map[:,1800:]
plt.imshow(right)

# %%
result = np.concatenate((left, right), axis=1)
plt.imshow(result)
cv.imwrite("new_map.png", result)
map = result

# %%
left = map[:, :500]
plt.imshow(left)

# %%
right = map[:, 600:]
plt.imshow(right)

# %%
result = np.concat((left, right), axis=1)
plt.imshow(result)
cv.imwrite("new_map.png", result)
# Out:
# True
